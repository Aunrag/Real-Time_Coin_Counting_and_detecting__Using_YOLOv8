# %%
# !pip install  ultralytics

# %%
from ultralytics import YOLO

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pradhandebasish/indian-coin-detection")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.95G/1.95G [01:11<00:00, 29.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/pradhandebasish/indian-coin-detection/versions/1

# %%
import cv2
import matplotlib.pyplot as plt
import os
dataset_path="/root/.cache/kagglehub/datasets/pradhandebasish/indian-coin-detection/versions/1/coins-data/images/train"
image_files=[f for f in os.listdir(dataset_path)]
image_files=image_files[:20]
plt.figure(figsize=(20,6))
for i,img_name in enumerate(image_files):
  img_path=os.path.join(dataset_path,img_name)
  img=cv2.imread(img_path)
  img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  plt.subplot(1,20,i+1)
  plt.imshow(img)
  plt.axis('off')
plt.show()

# %%
import os
dataset="/content/drive/MyDrive/yolo_dataset"
os.makedirs(dataset,exist_ok=True)

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/drive/MyDrive/yolo_dataset/data.yaml",
    epochs=80,
    imgsz=800,
    batch=8,
    device=0
)
# Out:
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp runs/detect/train/weights/best.pt /content/drive/MyDrive/yolo_dataset/coin_yolov8_best.pt

# %%
# !cp runs/detect/train2/weights/best.pt /content/drive/MyDrive/yolo_dataset/coin_yolov8_best.pt

# %%
# !cp runs/detect/train2/weights/last.pt /content/drive/MyDrive/yolo_dataset/coin_yolov8_last.pt

# %%
model=YOLO('/content/drive/MyDrive/yolo_dataset/coin_yolov8_best.pt')

# %%
result=model("/content/drive/MyDrive/yolo_dataset/input_yolo.jpeg", show=True, conf=0.5,save=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-722919272.py in <cell line: 0>()
# ----> 1 result=model("/content/drive/MyDrive/yolo_dataset/input_yolo.jpeg", show=True, conf=0.5,save=True)
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2470260163.py in <cell line: 0>()
# ----> 1 plt.imshow(result)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# ...
